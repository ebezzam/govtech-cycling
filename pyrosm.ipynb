# %%
from pyrosm import OSM
from pyrosm import get_data
# Out:
# /home/bezzam/miniconda3/envs/govtech/lib/python3.9/site-packages/pyrosm/utils/__init__.py:8: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %%
network_type = "cycling"
location = "switzerland"
location = "Zuerich"
# location = "test_pbf"

fp = get_data(location, directory=".")

# %%
osm = OSM(fp)
nodes, edges = osm.get_network(nodes=True, network_type=network_type)

# %%
edges
# Out:
#         access  area       bicycle bridge busway cycleway est_width  foot  \
# 0         None  None  use_sidepath    yes   None     None      None  None
# 1         None  None  use_sidepath    yes   None     None      None  None
# 2         None  None  use_sidepath    yes   None     None      None  None
# 3         None  None  use_sidepath    yes   None     None      None  None
# 4         None  None  use_sidepath    yes   None     None      None  None
# ...        ...   ...           ...    ...    ...      ...       ...   ...
# 1126989   None  None          None   None   None     None      None  None
# 1126990   None  None           yes   None   None     None      None  None
# 1126991   None  None           yes   None   None     None      None  None
# 1126992   None  None           yes   None   None     None      None  None
# 1126993   None  None           yes   None   None     None      None  None
#
#         footway    highway  ... width          id timestamp version  \
# 0          None  secondary  ...  None     1027169         0      -1
# 1          None  secondary  ...  None     1027169         0      -1
# 2          None  secondary  ...  None     1027169         0      -1
# 3          None  secondary  ...  None     1027169         0      -1
# 4          None  secondary  ...  None     1027169         0      -1
# ...         ...        ...  ...   ...         ...       ...     ...
# 1126989    None    service  ...  None  1153919305         0      -1
# 1126990    None    footway  ...  None  1153919306         0      -1
# 1126991    None    footway  ...  None  1153919306         0      -1
# 1126992    None    footway  ...  None  1153919306         0      -1
# 1126993    None    footway  ...  None  1153919306         0      -1
#
#                                                       tags osm_type  \
# 0        {"elevated":"+1","hazmat":"no","hgv":"no","lay...      way
# 1        {"elevated":"+1","hazmat":"no","hgv":"no","lay...      way
# 2        {"elevated":"+1","hazmat":"no","hgv":"no","lay...      way
# 3        {"elevated":"+1","hazmat":"no","hgv":"no","lay...      way
# 4        {"elevated":"+1","hazmat":"no","hgv":"no","lay...      way
# ...                                                    ...      ...
# 1126989                                               None      way
# 1126990                                               None      way
# 1126991                                               None      way
# 1126992                                               None      way
# 1126993                                               None      way
#
#                                                 geometry            u  \
# 0        LINESTRING (8.49523 47.39963, 8.49522 47.39959)    249091984
# 1        LINESTRING (8.49522 47.39959, 8.49489 47.39870)   1264083863
# 2        LINESTRING (8.49489 47.39870, 8.49483 47.39853)   1247641714
# 3        LINESTRING (8.49483 47.39853, 8.49478 47.39836)     92206459
# 4        LINESTRING (8.49478 47.39836, 8.49468 47.39811)   1770708062
# ...                                                  ...          ...
# 1126989  LINESTRING (8.33155 47.34943, 8.33147 47.34943)  10726899900
# 1126990  LINESTRING (8.32643 47.35597, 8.32633 47.35598)  10731772178
# 1126991  LINESTRING (8.32633 47.35598, 8.32628 47.35603)  10731772179
# 1126992  LINESTRING (8.32628 47.35603, 8.32624 47.35608)  10731772182
# 1126993  LINESTRING (8.32624 47.35608, 8.32572 47.35592)  10731772180
#
#                    v   length
# 0         1264083863    4.929
# 1         1247641714  102.151
# 2           92206459   19.371
# 3         1770708062   19.478
# 4         1336695313   28.756
# ...              ...      ...
# 1126989  10731772173    5.667
# 1126990  10731772179    8.010
# 1126991  10731772182    6.783
# 1126992  10731772180    6.352
# 1126993  10731772181   42.959
#
# [1126994 rows x 43 columns]

# %%
edges["bicycle"].value_counts()
# Out:
# yes             63464
# designated      27301
# use_sidepath     9628
# dismount          616
# private           593
# permissive        444
# no                368
# destination       250
# unknown            71
# mtb                60
# discouraged        17
# official           13
# delivery            3
# Name: bicycle, dtype: int64

# %%
# length in KM
edges["length"].sum() / 1000
# Out:
# 25288.672438999998

# %% [markdown]
# # filtering for a specific region
#
# https://pyrosm.readthedocs.io/en/latest/basics.html#filtering-data-based-on-bounding-box

# %%
from pyrosm import OSM
from pyrosm import get_data
# Out:
# /home/bezzam/miniconda3/envs/govtech/lib/python3.9/site-packages/pyrosm/utils/__init__.py:8: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %%
# Download a dataset for Greater London (update if exists in the temp already)
fp = get_data("Greater London", update=True)
osm = OSM(fp)
# Out:
# Downloaded Protobuf data 'greater-london-latest.osm.pbf' (86.86 MB) to:
# '/tmp/pyrosm/greater-london-latest.osm.pbf'

# %%
bounding_box = osm.get_boundaries(name="London Borough of Camden")
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
bounding_box
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 bounding_box
#
# NameError: name 'bounding_box' is not defined
